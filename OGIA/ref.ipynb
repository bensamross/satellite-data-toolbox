# %%
from osgeo import gdal

# %%
# filepath = r"LandsatData/LC81910182016153LGN00_sr_band4.tif"
filepath = r"G:\OGIA\B6_GWModel\M01_RegionalModel\2021\07_Model\1_Architecture\Structured_250m\Surfaces\L00_DEM_250m.ref"

# %%
# Open the file:
raster = gdal.Open(filepath)

# Check type of the variable 'raster'
type(raster)
# Out:
# osgeo.gdal.Dataset
