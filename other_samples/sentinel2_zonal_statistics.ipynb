# %% [markdown]
# # Zonal Statistics

# %% [markdown]
# Author: [Lukas Valentin Graf](https://github.com/lukasValentin/lukasValentin) (2022-2023)
#
# ## Learning Objectives
#
# In this notebook you will learn how to
#
# * calculate zonal statistics for agricultural field parcels
# * see how these statistics change over time
#
# ## Tutorial Content
#
# This tutorial is introductorial level.
#
# Basic knowledge about [GeoPandas](https://geopandas.org/en/stable/) and EOdal might be helpful. If you are unfamiliar with EOdal you might check out [these notebooks](../General) first.
#
# If you don't know about zonal statistics you might find reading [this blog](https://up42.com/blog/an-introduction-to-zonal-statistics) helpful.
#
# To run this notebook no additional requirements in terms of software-setup are necessary. It connects, however, to [Microsoft Planetary Computer](https://planetarycomputer.microsoft.com/). No authentication is required but stable internet connection is an asset.
#
# The data required to run this notebook can be found [here](./../data).

# %% [markdown]
# ### Preparing the environment

# %%
# %pip install scipy eodal
# Out:
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (1.16.1)
# Collecting eodal
#   Downloading eodal-0.2.4-py3-none-any.whl.metadata (8.9 kB)
# Requirement already satisfied: numpy<2.6,>=1.25.2 in /usr/local/lib/python3.11/dist-packages (from scipy) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from eodal) (2.2.2)
# Requirement already satisfied: geopandas in /usr/local/lib/python3.11/dist-packages (from eodal) (1.1.1)
# Requirement already satisfied: sqlalchemy in /usr/local/lib/python3.11/dist-packages (from eodal) (2.0.42)
# Collecting geoalchemy2 (from eodal)
#   Downloading geoalchemy2-0.18.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting pydantic-settings (from eodal)
#   Downloading pydantic_settings-2.10.1-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: pyproj in /usr/local/lib/python3.11/dist-packages (from eodal) (3.7.1)
# Collecting rasterio (from eodal)
#   Downloading rasterio-1.4.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.1 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from eodal) (3.10.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.11/dist-packages (from eodal) (5.4.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from eodal) (1.5.1)
# Collecting psycopg2-binary (from eodal)
#   Downloading psycopg2_binary-2.9.10-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.11/dist-packages (from eodal) (4.12.0.88)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from eodal) (2.32.3)
# Requirement already satisfied: xarray in /usr/local/lib/python3.11/dist-packages (from eodal) (2025.7.1)
# Collecting rtree (from eodal)
#   Downloading rtree-1.4.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.1 kB)
# Collecting zarr (from eodal)
#   Downloading zarr-3.1.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numba in /usr/local/lib/python3.11/dist-packages (from eodal) (0.60.0)
# Collecting pystac-client (from eodal)
#   Downloading pystac_client-0.9.0-py3-none-any.whl.metadata (3.1 kB)
# Collecting sentinelsat (from eodal)
#   Downloading sentinelsat-1.2.1-py3-none-any.whl.metadata (10 kB)
# Collecting python-dotenv (from eodal)
#   Downloading python_dotenv-1.1.1-py3-none-any.whl.metadata (24 kB)
# Collecting planetary-computer>=1.0.0 (from eodal)
#   Downloading planetary_computer-1.0.0-py3-none-any.whl.metadata (7.4 kB)
# Collecting alive-progress (from eodal)
#   Downloading alive_progress-3.3.0-py3-none-any.whl.metadata (72 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.7/72.7 kB 4.8 MB/s eta 0:00:00
# Collecting rasterstats (from eodal)
#   Downloading rasterstats-0.20.0-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from eodal) (6.0.2)
# Collecting myst-parser (from eodal)
#   Downloading myst_parser-4.0.1-py3-none-any.whl.metadata (5.5 kB)
# Collecting pyotp (from eodal)
#   Downloading pyotp-2.9.0-py3-none-any.whl.metadata (9.8 kB)
# Requirement already satisfied: click>=7.1 in /usr/local/lib/python3.11/dist-packages (from planetary-computer>=1.0.0->eodal) (8.2.1)
# Requirement already satisfied: pydantic>=1.7.3 in /usr/local/lib/python3.11/dist-packages (from planetary-computer>=1.0.0->eodal) (2.11.7)
# Collecting pystac>=1.0.0 (from planetary-computer>=1.0.0->eodal)
#   Downloading pystac-1.13.0-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: pytz>=2020.5 in /usr/local/lib/python3.11/dist-packages (from planetary-computer>=1.0.0->eodal) (2025.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from planetary-computer>=1.0.0->eodal) (25.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pystac-client->eodal) (2.9.0.post0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->eodal) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->eodal) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->eodal) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->eodal) (2025.8.3)
# Collecting about-time==4.2.1 (from alive-progress->eodal)
#   Downloading about_time-4.2.1-py3-none-any.whl.metadata (13 kB)
# Collecting graphemeu==0.7.2 (from alive-progress->eodal)
#   Downloading graphemeu-0.7.2-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy->eodal) (3.2.3)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy->eodal) (4.14.1)
# Requirement already satisfied: pyogrio>=0.7.2 in /usr/local/lib/python3.11/dist-packages (from geopandas->eodal) (0.11.1)
# Requirement already satisfied: shapely>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from geopandas->eodal) (2.1.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->eodal) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->eodal) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->eodal) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->eodal) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->eodal) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->eodal) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->eodal) (3.2.3)
# Requirement already satisfied: docutils<0.22,>=0.19 in /usr/local/lib/python3.11/dist-packages (from myst-parser->eodal) (0.21.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from myst-parser->eodal) (3.1.6)
# Requirement already satisfied: markdown-it-py~=3.0 in /usr/local/lib/python3.11/dist-packages (from myst-parser->eodal) (3.0.0)
# Requirement already satisfied: mdit-py-plugins>=0.4.1,~=0.4 in /usr/local/lib/python3.11/dist-packages (from myst-parser->eodal) (0.4.2)
# Requirement already satisfied: sphinx<9,>=7 in /usr/local/lib/python3.11/dist-packages (from myst-parser->eodal) (8.2.3)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba->eodal) (0.43.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic-settings->eodal) (0.4.1)
# Collecting affine (from rasterio->eodal)
#   Downloading affine-2.4.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: attrs in /usr/local/lib/python3.11/dist-packages (from rasterio->eodal) (25.3.0)
# Collecting cligj>=0.5 (from rasterio->eodal)
#   Downloading cligj-0.7.2-py3-none-any.whl.metadata (5.0 kB)
# Collecting click-plugins (from rasterio->eodal)
#   Downloading click_plugins-1.1.1.2-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting fiona (from rasterstats->eodal)
#   Downloading fiona-1.10.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.6/56.6 kB 3.7 MB/s eta 0:00:00
# Requirement already satisfied: simplejson in /usr/local/lib/python3.11/dist-packages (from rasterstats->eodal) (3.20.1)
# Collecting html2text (from sentinelsat->eodal)
#   Downloading html2text-2025.4.15-py3-none-any.whl.metadata (4.1 kB)
# Collecting geojson>=2 (from sentinelsat->eodal)
#   Downloading geojson-3.2.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: tqdm>=4.58 in /usr/local/lib/python3.11/dist-packages (from sentinelsat->eodal) (4.67.1)
# Collecting geomet (from sentinelsat->eodal)
#   Downloading geomet-1.1.0-py3-none-any.whl.metadata (11 kB)
# Collecting donfig>=0.8 (from zarr->eodal)
#   Downloading donfig-0.8.1.post1-py3-none-any.whl.metadata (5.0 kB)
# Collecting numcodecs>=0.14 (from numcodecs[crc32c]>=0.14->zarr->eodal)
#   Downloading numcodecs-0.16.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.3 kB)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py~=3.0->myst-parser->eodal) (0.1.2)
# Collecting crc32c>=2.7 (from numcodecs[crc32c]>=0.14->zarr->eodal)
#   Downloading crc32c-2.7.1-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.3 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=1.7.3->planetary-computer>=1.0.0->eodal) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=1.7.3->planetary-computer>=1.0.0->eodal) (2.33.2)
# Requirement already satisfied: jsonschema~=4.18 in /usr/local/lib/python3.11/dist-packages (from pystac[validation]>=1.10.0->pystac-client->eodal) (4.25.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pystac-client->eodal) (1.17.0)
# Requirement already satisfied: sphinxcontrib-applehelp>=1.0.7 in /usr/local/lib/python3.11/dist-packages (from sphinx<9,>=7->myst-parser->eodal) (2.0.0)
# Requirement already satisfied: sphinxcontrib-devhelp>=1.0.6 in /usr/local/lib/python3.11/dist-packages (from sphinx<9,>=7->myst-parser->eodal) (2.0.0)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.6 in /usr/local/lib/python3.11/dist-packages (from sphinx<9,>=7->myst-parser->eodal) (2.1.0)
# Requirement already satisfied: sphinxcontrib-jsmath>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from sphinx<9,>=7->myst-parser->eodal) (1.0.1)
# Requirement already satisfied: sphinxcontrib-qthelp>=1.0.6 in /usr/local/lib/python3.11/dist-packages (from sphinx<9,>=7->myst-parser->eodal) (2.0.0)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.9 in /usr/local/lib/python3.11/dist-packages (from sphinx<9,>=7->myst-parser->eodal) (2.0.0)
# Requirement already satisfied: Pygments>=2.17 in /usr/local/lib/python3.11/dist-packages (from sphinx<9,>=7->myst-parser->eodal) (2.19.2)
# Requirement already satisfied: snowballstemmer>=2.2 in /usr/local/lib/python3.11/dist-packages (from sphinx<9,>=7->myst-parser->eodal) (3.0.1)
# Requirement already satisfied: babel>=2.13 in /usr/local/lib/python3.11/dist-packages (from sphinx<9,>=7->myst-parser->eodal) (2.17.0)
# Requirement already satisfied: alabaster>=0.7.14 in /usr/local/lib/python3.11/dist-packages (from sphinx<9,>=7->myst-parser->eodal) (1.0.0)
# Requirement already satisfied: imagesize>=1.3 in /usr/local/lib/python3.11/dist-packages (from sphinx<9,>=7->myst-parser->eodal) (1.4.1)
# Requirement already satisfied: roman-numerals-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from sphinx<9,>=7->myst-parser->eodal) (3.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->myst-parser->eodal) (3.0.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac-client->eodal) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac-client->eodal) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac-client->eodal) (0.26.0)
# Downloading eodal-0.2.4-py3-none-any.whl (195 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.4/195.4 kB 9.7 MB/s eta 0:00:00
# Downloading planetary_computer-1.0.0-py3-none-any.whl (14 kB)
# Downloading pystac_client-0.9.0-py3-none-any.whl (41 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.8/41.8 kB 3.4 MB/s eta 0:00:00
# Downloading alive_progress-3.3.0-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 kB 5.3 MB/s eta 0:00:00
# Downloading about_time-4.2.1-py3-none-any.whl (13 kB)
# Downloading graphemeu-0.7.2-py3-none-any.whl (22 kB)
# Downloading geoalchemy2-0.18.0-py3-none-any.whl (81 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.2/81.2 kB 4.9 MB/s eta 0:00:00
# Downloading myst_parser-4.0.1-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.6/84.6 kB 5.4 MB/s eta 0:00:00
# Downloading psycopg2_binary-2.9.10-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 42.3 MB/s eta 0:00:00
# Downloading pydantic_settings-2.10.1-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.2/45.2 kB 3.0 MB/s eta 0:00:00
# Downloading python_dotenv-1.1.1-py3-none-any.whl (20 kB)
# Downloading pyotp-2.9.0-py3-none-any.whl (13 kB)
# Downloading rasterio-1.4.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (22.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.2/22.2 MB 39.9 MB/s eta 0:00:00
# Downloading rasterstats-0.20.0-py3-none-any.whl (17 kB)
# Downloading rtree-1.4.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (541 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 541.1/541.1 kB 22.7 MB/s eta 0:00:00
# Downloading sentinelsat-1.2.1-py3-none-any.whl (48 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.8/48.8 kB 2.8 MB/s eta 0:00:00
# Downloading zarr-3.1.1-py3-none-any.whl (255 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 255.4/255.4 kB 11.0 MB/s eta 0:00:00
# Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Downloading donfig-0.8.1.post1-py3-none-any.whl (21 kB)
# Downloading geojson-3.2.0-py3-none-any.whl (15 kB)
# Downloading numcodecs-0.16.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 43.9 MB/s eta 0:00:00
# Downloading pystac-1.13.0-py3-none-any.whl (206 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 206.8/206.8 kB 13.7 MB/s eta 0:00:00
# Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Downloading click_plugins-1.1.1.2-py2.py3-none-any.whl (11 kB)
# Downloading fiona-1.10.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 38.9 MB/s eta 0:00:00
# Downloading geomet-1.1.0-py3-none-any.whl (31 kB)
# Downloading html2text-2025.4.15-py3-none-any.whl (34 kB)
# Downloading crc32c-2.7.1-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.7/53.7 kB 4.0 MB/s eta 0:00:00
# Installing collected packages: rtree, python-dotenv, pyotp, psycopg2-binary, numcodecs, html2text, graphemeu, geomet, geojson, donfig, crc32c, cligj, click-plugins, affine, about-time, sentinelsat, rasterio, pystac, geoalchemy2, fiona, alive-progress, zarr, rasterstats, pydantic-settings, myst-parser, pystac-client, planetary-computer, eodal
# Successfully installed about-time-4.2.1 affine-2.4.0 alive-progress-3.3.0 click-plugins-1.1.1.2 cligj-0.7.2 crc32c-2.7.1 donfig-0.8.1.post1 eodal-0.2.4 fiona-1.10.1 geoalchemy2-0.18.0 geojson-3.2.0 geomet-1.1.0 graphemeu-0.7.2 html2text-2025.4.15 myst-parser-4.0.1 numcodecs-0.16.1 planetary-computer-1.0.0 psycopg2-binary-2.9.10 pydantic-settings-2.10.1 pyotp-2.9.0 pystac-1.13.0 pystac-client-0.9.0 python-dotenv-1.1.1 rasterio-1.4.3 rasterstats-0.20.0 rtree-1.4.0 sentinelsat-1.2.1 zarr-3.1.1

# %%
import geopandas as gpd
import numpy as np

from datetime import datetime
from eodal.config import get_settings
from eodal.core.scene import SceneCollection
from eodal.core.sensors.sentinel2 import Sentinel2
from eodal.mapper.feature import Feature
from eodal.mapper.filter import Filter
from eodal.mapper.mapper import Mapper, MapperConfigs
from scipy.stats import median_abs_deviation

from pathlib import Path
from typing import List

Settings = get_settings()
# set to False to use a local data archove
Settings.USE_STAC = True

# %%
# check EOdal version
import eodal
print(f'The EOdal version is {eodal.__version__}')
# Out:
# The EOdal version is 0.2.4

# %% [markdown]
# ### Defining custom metrics for zonal statistics
#
# EOdal makes use of the [rasterstats](https://pythonhosted.org/rasterstats/) package to calculate zonal statistics. The cool thing about `rasterstats` is its ability to take custom functions as an input for calculating user-defined statistical metrics. This means, users will have a lot of freedom choicing the metrics most suited to their needs.
#
# Below you find two examples of such custom functions. There are two important things to consider when writing user-defined functions:
#
# 1. the *function name* should be unique and not have the same name as any existing numpy function. Therefore, using a prefix such as `my_` might be helpful.
# 2. the *function should return a single scalar* as this is the definition of doing zonal statistics. *N* raster cells overlapping a geometry are aggregated by the function into a single value.
#
# The two functions below calculate the `median absolute deviation` and the `sum of the square` of the raster cell values. This has no deeper meaning and is just to show how such custom functions should be designed.

# %%
def my_median_abs_deviation(x: np.ma.MaskedArray) -> float:
    """
    Custom function to calculate the median absolute
    deviation in `eodal.scene.get_feature_timeseries()`.

    :param x:
        array with raster values
    :returns:
        median absolute deviation value
    """
    x = x.filled(np.nan)
    return median_abs_deviation(x, nan_policy='omit', axis=None)

# %%
def my_square_sum(x: np.ma.MaskedArray) -> float:
    """
    Custom function returning sum(x**2)

    :param x:
        array with raster values
    :returns:
        median absolute deviation value
    """
    x = x.filled(np.nan)
    # important: the sum of nan is zero!
    if np.isnan(x).all():
        return np.nan
    return np.nansum(x*x)

# %% [markdown]
# ### Getting the Sentinel-2 Data
#
# This part of the notebook is essentially the same as in the [EOdal mapper notebook](../General/EOdal_Mapper.ipynb). We therefore don't repeat explainations here and recommened to have a look at the aforementioned notebook for details.

# %%
def preprocess_sentinel2_scenes(
    ds: Sentinel2,
    target_resolution: int,
) -> Sentinel2:
    """
    Resample Sentinel-2 scenes and mask clouds, shadows, and snow
    based on the Scene Classification Layer (SCL).

    NOTE:
        Depending on your needs, the pre-processing function can be
        fully customized using the full power of EOdal and its
        interfacing libraries!

    :param target_resolution:
        spatial target resolution to resample all bands to.
    :returns:
        resampled, cloud-masked Sentinel-2 scene.
    """
    # resample scene
    ds.resample(inplace=True, target_resolution=target_resolution)
    # mask clouds, shadows, and snow
    ds.mask_clouds_and_shadows(inplace=True)
    return ds

# %%
#%% user-inputs
# -------------------------- Collection -------------------------------
collection: str = 'sentinel2-msi'

# ------------------------- Time Range ---------------------------------
time_start: datetime = datetime(2022,3,1)  		# year, month, day (incl.)
time_end: datetime = datetime(2022,5,1)   		# year, month, day (incl.)

# ---------------------- Spatial Feature  ------------------------------
geom: Path = Path('data/sample_polygons/ZH_Polygons_2020_ESCH_EPSG32632.shp')

# ------------------------- Metadata Filters ---------------------------
metadata_filters: List[Filter] = [
    Filter('cloudy_pixel_percentage','<', 80),
    Filter('processing_level', '==', 'Level-2A')
]

# %%
#%% query the scenes available (no I/O of scenes, this only fetches metadata)
feature = Feature.from_geoseries(gpd.read_file(geom).geometry)
mapper_configs = MapperConfigs(
    collection=collection,
    time_start=time_start,
    time_end=time_end,
    feature=feature,
    metadata_filters=metadata_filters
)
mapper_configs
# Out:
# ---------------------------------------------------------------------------
# DataSourceError                           Traceback (most recent call last)
# /tmp/ipython-input-1852197615.py in <cell line: 0>()
#       1 #%% query the scenes available (no I/O of scenes, this only fetches metadata)
# ----> 2 feature = Feature.from_geoseries(gpd.read_file(geom).geometry)
#       3 mapper_configs = MapperConfigs(
#       4     collection=collection,
#       5     time_start=time_start,
#
# /usr/local/lib/python3.11/dist-packages/geopandas/io/file.py in _read_file(filename, bbox, mask, columns, rows, engine, **kwargs)
#     314
#     315     if engine == "pyogrio":
# --> 316         return _read_file_pyogrio(
#     317             filename, bbox=bbox, mask=mask, columns=columns, rows=rows, **kwargs
#     318         )
#
# /usr/local/lib/python3.11/dist-packages/geopandas/io/file.py in _read_file_pyogrio(path_or_bytes, bbox, mask, rows, **kwargs)
#     574         kwargs["columns"] = kwargs.pop("include_fields")
#     575
# --> 576     return pyogrio.read_dataframe(path_or_bytes, bbox=bbox, **kwargs)
#     577
#     578
#
# /usr/local/lib/python3.11/dist-packages/pyogrio/geopandas.py in read_dataframe(path_or_buffer, layer, encoding, columns, read_geometry, force_2d, skip_features, max_features, where, bbox, mask, fids, sql, sql_dialect, fid_as_index, use_arrow, on_invalid, arrow_to_pandas_kwargs, **kwargs)
#     273         # as numpy does not directly support timezones.
#     274         kwargs["datetime_as_string"] = True
# --> 275     result = read_func(
#     276         path_or_buffer,
#     277         layer=layer,
#
# /usr/local/lib/python3.11/dist-packages/pyogrio/raw.py in read(path_or_buffer, layer, encoding, columns, read_geometry, force_2d, skip_features, max_features, where, bbox, mask, fids, sql, sql_dialect, return_fids, datetime_as_string, **kwargs)
#     196     dataset_kwargs = _preprocess_options_key_value(kwargs) if kwargs else {}
#     197
# --> 198     return ogr_read(
#     199         get_vsi_path_or_buffer(path_or_buffer),
#     200         layer=layer,
#
# pyogrio/_io.pyx in pyogrio._io.ogr_read()
#
# pyogrio/_io.pyx in pyogrio._io.ogr_open()
#
# DataSourceError: ../../data/sample_polygons/ZH_Polygons_2020_ESCH_EPSG32632.shp: No such file or directory

# %%
# now, a new Mapper instance is created
mapper = Mapper(mapper_configs)
mapper.query_scenes()
# the metadata is loaded into a GeoPandas GeoDataFrame
mapper.metadata

# %%
#%% load the scenes available from STAC
scene_kwargs = {
    'scene_constructor': Sentinel2.from_safe,
    'scene_constructor_kwargs': {'band_selection': ['B02', 'B03', 'B04', 'B08']},
    'scene_modifier': preprocess_sentinel2_scenes,
    'scene_modifier_kwargs': {'target_resolution': 10}
}
mapper.load_scenes(scene_kwargs=scene_kwargs)
scoll = mapper.data
scoll

# %% [markdown]
# ### Calculationg zonal statistics
#
# With the cells above we have loaded multiple scenes at once into a `SceneCollection`. We can now either calculate the zonal statistics per scene (which would be done using `RasterCollection.band_summaries()`) or make use of the `SceneCollection.get_feature_timeseries()` method that calls `RasterCollection.band_summaries()` for each scene and stacks the results into a single `GeoDataFrame`.
#
# In the example below, we calculate two vegetation indices, namely the [NDVI](https://gisgeography.com/ndvi-normalized-difference-vegetation-index/) and the [MSAVI](https://eos.com/industries/agriculture/msavi/), and calculate zonal statistics per single field parcel and Sentinel-2 scene.

# %%
# calculate spectral indices
for _, scene in scoll:
    scene.calc_si('NDVI', inplace=True)
    scene.calc_si('MSAVI', inplace=True)

# %%
# get time series of the field parcel using a bunch of statistical metrics
ts = scoll.get_feature_timeseries(
    vector_features=geom,
    method=['percentile_10', 'percentile_50', 'median', 'mean', 'percentile_90', my_square_sum, my_median_abs_deviation],
    band_selection=['ndvi', 'msavi']
)
ts

# %% [markdown]
# ### Plotting Time Series
#
# We can now plot time series values per field parcel using e.g., the median NDVI and MSAVI value per parcel and Sentinel-2 acquisition date.

# %%
# %pip install seaborn

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('tableau-colorblind10')

# convert timestamps to get a nicely formatted x axis
ts.acquisition_time = pd.to_datetime(ts.acquisition_time)
f, ax = plt.subplots(ncols=2, figsize=(20,10))
ts_sis = ts.groupby(ts.band_name)

idx = 0
for si, ts_si in ts_sis:
    sns.lineplot(x='acquisition_time', y='median', hue='GIS_ID', data=ts_si, ax=ax[idx])
    ax[idx].set_title(si.upper())
    idx += 1

# %% [markdown]
# Since `ts` is a `GeoDataFrame` all results can be also visualized on a map or saved as, e.g., GeoPackage file for further analysis.

# %%
ts.plot(column='NUTZUNGSCO')
